# %% [markdown]
# # Linear Regression

# %% [markdown]
# #### Imagine you have a friend, Alex, who collects stamps. Every month, Alex buys a certain number of stamps, and you notice that the amount Alex spends seems to depend on the number of stamps bought. Now, you want to create a little tool that can predict how much Alex will spend next month based on the number of stamps bought. This is where Linear Regression comes into play. In technical terms, we're trying to predict the dependent variable (amount spent) based on the independent variable (number of stamps bought).

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
stamps_bought = np.array([1, 3, 5, 7, 9]).reshape(-1, 1)
amount_spent = np.array([2, 6, 8, 12, 18])
# Creating a Linear Regression Model
model = LinearRegression()
# Training the Model
model.fit(stamps_bought, amount_spent)
next_month_stamps = 10
predicted_spend = model.predict([[next_month_stamps]])
plt.scatter(stamps_bought, amount_spent, color='blue')
plt.plot(stamps_bought, model.predict(stamps_bought), color='red');
plt.grid(True)
plt.show()
print(f"If Alex buys {next_month_stamps} stamps next month, they will likely spend ${predicted_spend[0]:.2f}.")
# Out:
# If Alex buys 10 stamps next month, they will likely spend $18.70.
